# %% [markdown]
# # Audio Features: Đặc trưng Cepstral

# %% [markdown]
# Nếu như Spectral (spectrum, phổ tín hiệu) có được bằng cách thực hiện biến đổi Fourier rời rạc (DFT) thì đặc trưng Cepstral có được bằng cách biến đổi DFT (hoặc DCT) spectrum của tín hiệu đó. Các đăch trưng cepstral như Mel-frequency cepstral coefficients (MFCC) được sử dụng rộng rãi trong các bài toán xử lý tiếng nói vì tính trực quan của nó. Trong bài này mình sẽ giới thiệu hai đặc trưng cepstral phổ biến là MFCC và Gammatone Frequency Cepstral coefficients (GFCC)

# %% [markdown]
# # Mel-frequency cepstral coefficents

# %% [markdown]
# Trong xử lý âm thanh, mel-frequency cepstrum (MFC) là một biểu diễn của phổ năng lượng ngắn hạn của âm thanh, dựa trên biến đổi cosine tuyến tính của logarit năng lượng trên thang tần số mel phi tuyến. Mel-frequency cepstral coefficients (MFCC) là các hệ số tạo thành một MFC. Thang tần số Mel được định nghĩa như sau:

# %% [markdown]
# $$
# m = 2595.log_{10}(1 + \frac{f}{700})
# $$

# %% [markdown]
# ![](image1.png)

# %% [markdown]
# Để trích xuất MFCC, sau khi chia âm thanh dạng waveform thành các frame, ta biến đổi Fourier rời rạc trên frame đó:

# %% [markdown]
# $$
# S_{i}(k) = \sum^{N}_{n=1}{s_{i}(n)h(n)e^{-j2\pi n\frac{k}{N}}}
# $$
# $$
# 1 \leq k \leq K
# $$
#
# - Trong đó $h(n)$ là cửa số phân tích (Hamming, Hanning, ...) độ dài N và K là độ dài của DFT

# %% [markdown]
# Sau đó, power spectrum $P_{i}$ của $S_{i}$ được tính bằng công thức:

# %% [markdown]
# $$
# P_{i}(k) = \frac{1}{N}|S_{i}(k)|^2
# $$

# %% [markdown]
# Bằng cách lấy một tần số $f_{k}$, ta sẽ ánh xạ được sang tần số $m_{k}$ trên thang Mel. Tuy nhiên, nếu chỉ chọn mẫu ở tần số $f_{k}$, chúng ta sẽ mất tất cả các thông tin khác. Do đó, ta lấy tổng năng lượng có trọng số gần tần số mục tiêu $f_{k}$ trên power spectrum $P_{i}$ bằng công thức:

# %% [markdown]
# $$
# u_{k} = \sum^{f_{k+1} - 1}_{h=f_{k - 1}+1}{w_{k,h}|x_{h}|^2}
# $$

# %% [markdown]
# Trong đó $w_{k}, h$ là trọng số ứng với mẫu $x_{h}$ và thường là các bộ lọc tam giác:

# %% [markdown]
# $$
# w_{k,h} =
# \begin{cases}
# \frac{h-f_{k-1}}{f_{k}-f_{k-1}} & for \space f_{k-1} < h \leq f_{k} \\
# \frac{f_{k+1}-h}{f_{k+1}-f_{k}} & for \space f_{k} < h \leq f_{k+1} \\
# 0 & otherwise
# \end{cases}
# $$

# %% [markdown]
# ![](image2.png)

# %% [markdown]
# - mô phỏng độ nhạy tai người theo Mel scale
# - mỗi filter phải thu thập năng lượng trong một vùng tần số
# - các filter phải chồng lên nhau mượt để không mất thông tin

# %% [markdown]
# Cuối cùng, bằng cách biến đổi cosine rời rác (DCT) của các tham số $u_{k}$, chúng ta có được biểu diễn được gọi là Mel-frequency cepstral coefficents (MFCC). Tác dụng của DCT là làm giảm sự tuyến tính, sao cho các hệ số MFC không tương quan với nhau.

# %% [markdown]
# ![](image3.png)

# %% [markdown]
# - từ trái qua phải: spectrogram, mel-spectrogram, MFCC

# %% [markdown]
# Một số ưu điểm của MFCC:

# %% [markdown]
# - Loại bỏ những thông tin quá chi tiết (thường là dư thừa) và tập trung vào những thông tin về cấu trúc âm thanh (thường quan trọng hơn).
# - Dễ hiểu và tính toán dễ dàng.
# - Hiệu quả đã được kiểm chứng.

# %% [markdown]
# Những vấn đề của MFCC:

# %% [markdown]
# - Việc lựa chọn thang Mel chưa được kiểm chứng chặt chẽ bằng toán học. Các thang đo như ERB hoặc gammatone filterbank có thể phù hợp hơn. Tuy nhiên, các bộ lọc thay thế này không cho thấy lợi ích nhất quán trong các bài toán khác nhau, do đó thang đo mel vẫn được sử dụng.
# - Nhạy cảm với nhiễu. Hiệu suât của các MFCC khi tín hiệu xuất hiện nhiễu, so với các đặc trưng khác không phải lúc nào cũng tốt hơn.
# - Sự lựa chọn các bộ lọc tam giác thường là tự ý và không dựa trên một lập luận vững chắc nào.
# - Hoạt động tốt trong bài toán phân tích(analysis) nhưng không tốt trong bài toán tổng hợp(synthesis). Việc biến đổi ngược từ MFCC sang spectrogram rất khó khăn.

# %% [markdown]
# # Gammatone Frequency Cepstral Coefficients

# %% [markdown]
# Một trong những vấn đề lớn nhất trong nhận diện âm thanh là tiếng ồn/nhiễu. Độ nhạy đối với nhiễu, như đã đề cập ở trên, là một trong những nhược điểm chính của MFCC. GFCC là đặc trưng dựa trên một tập hợp các bộ lọc Gammatone. Đầu ra của bộ lọc gammatone là một biểu diễn trên miền thời gian-tần số, được gọi là cochleagram. Để tính toán GFCC, ta cần phải trích xuất cochleagram; các bước tính toán khác có nhiều điểm tương đồng với MFCC.

# %% [markdown]
# Đầu tiên, ta cũng thực hiện biến đổi STFT trên tín hiệu đầu vào:

# %% [markdown]
# $$
# S_{i}(k) = \sum^{N}_{n=1}{s_{i}(n)h(n)e^{-j2\pi n\frac{k}{N}}}
# $$
# $$
# 1 \leq k \leq K
# $$
#
# - Trong đó $h(n)$ là cửa số phân tích (Hamming, Hanning, ...) độ dài N và K là độ dài của DFT

# %% [markdown]
# Sau đó trích xuất power cepstrum trước khi nhân chập với các bộ lọc Gammatone:

# %% [markdown]
# $$
# P_{i}(k) = \frac{1}{N}|S_{i}(k)|^2
# $$

# %% [markdown]
# Các bộ lọc Gammatone được thiết kế để mô phỏng quá trình xử lý tín hiệu của hệ thống thính giác của con người. Bộ lọc Gammatone có tần số trung tâm $f_{c}$ được định nghĩa là:

# %% [markdown]
# $$
# g(t) = \alpha t^{n-1}e^{-2\pi bt}cos(2\pi f_{c} + \phi)
# $$

# %% [markdown]
# Trong đó $\phi$ là pha nhưng thường được đặt thành 0, hằng số $\alpha$ điều khiển độ tăng (gain) và bậc của bộ lọc được xác định bởi giá trị $n$ (thường được đặt thành giá trị nhỏ hơn 4). Tham số b được định nghĩa là:

# %% [markdown]
# $$
# b = 25,17.(\frac{4,37f_{c}}{1000} + 1)
# $$

# %% [markdown]
# Hình dứoi đây mô tả đáp ứng tần số của các bộ lọc gammatone.

# %% [markdown]
# ![](image4.png)

# %% [markdown]
# Ta thực hiện nhân chập với bộ lọc Gammatone để tạo ra Cochleagram:

# %% [markdown]
# $$
# u_{k} = \sum^{f_{k+1} - 1}_{h=f_{k-1} + 1}{w_{k,h}|x_{h}|^2}
# $$

# %% [markdown]
# Cochleagram được trích xuất tương tự như Mel-spectrogram trong MFCC, chỉ khác một điều rằng thay vì sử dụng bộ lọc tam giác như MFCC, ta sử dụng bộ lọc Gammatone như trên.

# %% [markdown]
# Biến đổi cosine rời rạc được áp dụng để thu được các hệ số cepstral phi tuyến. Tương tự như thao tác trên MFCC, hàm log được sử dụng trên spectrum $y(n,i)$:

# %% [markdown]
# $$
# g(n;u) = (\frac{2}{M})^{0.5}.\sum^{M-1}_{i=0}{\frac{1}{3}.log(\overline{y}(n;i)).cos[\frac{\pi u}{2M}(2i-1)]}
# $$

# %% [markdown]
# trong đó khoảng giá trị của $u$ thường là từ 0 đến 31. 12 hệ số đầu tiên sau đó được chọn ra để tạo thành GFCC 12 chiều:

# %% [markdown]
# $$
# g(n) = [g(n;0),...g(n;11)]^T
# $$

# %% [markdown]
# Ưu điểm của GFCC là ít nhạy cảm với nhiễu (so với MFCC) và mang nhiều thông tin ở vùng tần số thấp, dẫn đến phù hợp với các bàn toán xử lý tiếng nói. Tuy nhiên hiệu suất của GFCC cũng không nhất quán giữa các bài toán khác nhau và nó cũng ít được sử dụng hơn MFCC.

# %% [markdown]
# # Kết luận

# %% [markdown]
# Hai đặc trưng MFCC và GFCC rất hiệu quả trong các bài toán tiếng nói. Chúng là những biểu diễn đủ tốt và đủ nhỏ nên hay được sử dụng cho các thuật toán Machine Learning. Đối với Deep Learning, các phiên bản spectrogram của hai đặc trưng này, là mel-spectrogram và cochleagram, được ưu ái hơn do chúng giữ lại nhiều thông tin, giúp các mô hình học sâu tự trích xuất được các đặc trưng hữu ích
