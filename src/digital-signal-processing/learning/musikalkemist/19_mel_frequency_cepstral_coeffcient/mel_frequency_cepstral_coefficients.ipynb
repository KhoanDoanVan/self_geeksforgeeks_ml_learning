# %% [markdown]
# # Computing the cepstrum

# %% [markdown]
# $$
# C(x(t)) = F^{-1}[log(F[x(t)])]
# $$

# %% [markdown]
# ![](image1.png)

# %% [markdown]
# ![](image2.png)

# %% [markdown]
# # Visualising the cepstrum

# %% [markdown]
# ![](image3.png)

# %% [markdown]
# ![](image4.png)

# %% [markdown]
# ![](image5.png)

# %% [markdown]
# Fundamental Frequency:
# - $f_{0}$
# - if complex signal has many harmonics, then $f_{0}$ is the first.
# - Others harmonic are integer multiple of $f_{0}$
# - $f_{0}$ decided pitch, also harmonic decided timbre.

# %% [markdown]
# ![](image6.png)

# %% [markdown]
# - The application of Cepstrum is pitch detection

# %% [markdown]
# Why get Ceptrum is important and why we bother taking the inverse discrete fourier transform of the log power spectrum?

# %% [markdown]
# # The vocal track

# %% [markdown]
# ![](image7.png)

# %% [markdown]
# - Vocal track acts as a filter

# %% [markdown]
# # Speech Generation

# %% [markdown]
# ![](image8.png)

# %% [markdown]
# # Understanding the cepstrum

# %% [markdown]
# ![](image9.png)

# %% [markdown]
# Speech = Convolution of vocal tract frequency response with glottal pulse

# %% [markdown]
# # Formalising speech

# %% [markdown]
# $$
# x(t) = e(t).h(t)
# $$
#
# - x(t): speech signal
# - e(t): vocal tract frequency response
# - h(t): glottal pulse

# %% [markdown]
# Apply the FT:

# %% [markdown]
# $$
# X(t) = E(t).H(t)
# $$
#
# - X(t): spectrum * speech signal
# - E(t): spectra vocal tract frequency response
# - H(t): spectra glotta pulse

# %% [markdown]
# Apply logarithm:

# %% [markdown]
# $$
# log(X(t)) = log(E(t).H(t))
# $$
# $$\downarrow$$
# $$
# log(X(t)) = log(E(t))+log(H(t))
# $$

# %% [markdown]
# - log(X(t)): speech
# - log(E(t)): vocal tract frequency response
# - log(H(t)): glottal pulse

# %% [markdown]
# ![](image10.png)

# %% [markdown]
# # The goal: Seprating components

# %% [markdown]
# ![](image11.png)

# %% [markdown]
# - pitch is important but not really that important what we really care about is the identity of sound

# %% [markdown]
# $\rightarrow$ what we want to get is set of features that is timer, formants

# %% [markdown]
# # Separating components

# %% [markdown]
# ![](image12.png)

# %% [markdown]
# ![](image13.png)

# %% [markdown]
# ![](image15.png)

# %% [markdown]
# # Computing Mel-Frequency Cepstral Coefficients

# %% [markdown]
# ![](image16.png)

# %% [markdown]
# # Why Discrete Cosine Transform

# %% [markdown]
# - Simplified version of Fourier Transform
# - Get Read-valued coefficient
# - Decorrelate energy in different mel bands
# - Reduce dimensions to represent spectrum

# %% [markdown]
# # How many coefficients?

# %% [markdown]
# - Traditionally: first 12 - 13 coefficients
# - First coefficients keep most information (e.g, formants, spectral envelope)
# - Use $\triangle$ and $\triangle\triangle$ MFCCs
# - Total 39 coefficients per frame

# %% [markdown]
# # Visualising MFCCs

# %% [markdown]
# ![](image17.png)

# %% [markdown]
# # MFCCs advantages

# %% [markdown]
# - Describe the "large" structures of the spectrum
# - Ignore fine spectral structures
# - Work well in speech and music processing

# %% [markdown]
# # MFCCs disadvantages

# %% [markdown]
# - Not robust to noise
# - Extensive knowledge engineering
# - Not efficient for synthesis

# %% [markdown]
# # MFCCs applications

# %% [markdown]
# - Speech processing: Speech recognition, Speaker recognition, ...
# - Music processing: Music genre classification, Mood classification, Automatic tagging, ...
