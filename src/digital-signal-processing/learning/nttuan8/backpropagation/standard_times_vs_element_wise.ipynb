# %% [markdown]
# # 🔬 Phân tích các Phép nhân Ma trận trong Neural Networks (ML/DL)
#
# Tài liệu này so sánh hai phép toán ma trận cốt lõi: **Tích Ma trận Tiêu chuẩn** (Matrix Multiplication) và **Tích Hadamard** (Element-wise Multiplication), cùng với ứng dụng của chúng trong quá trình lan truyền xuôi và lan truyền ngược của Mạng Nơ-ron (Neural Networks).
#
# ---
#
# ## 1. 🆚 So Sánh Tổng quan
#
# | Đặc điểm | Tích Ma trận Tiêu chuẩn ($\cdot$ hoặc $*$) | Tích Hadamard ($\odot$ hoặc $\otimes$) |
# | :--- | :--- | :--- |
# | **Ký hiệu** | $*$, $\cdot$ | $\odot$, $\otimes$ |
# | **Ứng dụng chính trong NN** | **Lan truyền xuôi (Forward Prop.)** và **Lan truyền ngược (Backprop.)** qua Ma trận Trọng số ($W$). | **Áp dụng Đạo hàm Hàm Kích hoạt** lên Gradient (trong Backprop.). |
# | **Điều kiện Kích thước** | Số cột Ma trận 1 = Số hàng Ma trận 2. | Phải có cùng kích thước (Hàng = Hàng, Cột = Cột). |
# | **Công thức (Ví dụ $C=A \cdot B$)** | $C_{ij} = \sum_{k} A_{ik} B_{kj}$ | $C_{ij} = A_{ij} \cdot B_{ij}$ |
# | **Ý nghĩa** | Biểu diễn **Biến đổi Tuyến tính** (Linear Transformation) | Biểu diễn **Phép toán trên từng phần tử** độc lập. |
#
# ---
#
# ## 2. Ứng dụng Chi tiết trong Neural Networks
#
# ### 2.1. Tích Ma trận Tiêu chuẩn ($*$) - (Dot Product)
#
# Phép nhân ma trận là nền tảng cho **quá trình biến đổi tuyến tính** của dữ liệu.
#
# #### A. Lan truyền Xuôi (Forward Propagation)
# $$Z^{(i)} = W^{(i)} A^{(i-1)} + b^{(i)}$$
#
# * **Mục đích:** Tính đầu vào chưa kích hoạt ($Z$) của tầng $i$. Đây là sự kết hợp tuyến tính của Output tầng trước ($A^{(i-1)}$) với Trọng số ($W^{(i)}$).
#
# #### B. Lan truyền Ngược (Backpropagation)
# $$\frac{\partial J}{\partial A^{(i-1)}} = \frac{\partial J}{\partial Z^{(i)}} * (W^{(i)})^T$$
#
# * **Mục đích:** Lan truyền Gradient ($\frac{\partial J}{\partial Z^{(i)}}$) qua ma trận Trọng số chuyển vị $(W^{(i)})^T$ để tìm Gradient cho Output của tầng trước ($A^{(i-1)}$).
#
# **Ví dụ:**
# $$W = \begin{pmatrix} 0.5 & 0.1 \\ 0.2 & 0.6 \end{pmatrix}, \quad A_{\text{Input}} = \begin{pmatrix} 4 \\ 2 \end{pmatrix}$$
# $$Z = W \cdot A_{\text{Input}} = \begin{pmatrix} 0.5 \cdot 4 + 0.1 \cdot 2 \\ 0.2 \cdot 4 + 0.6 \cdot 2 \end{pmatrix} = \begin{pmatrix} 2.2 \\ 2.0 \end{pmatrix}$$
#
# ---
#
# ### 2.2. Tích Hadamard ($\odot$ hoặc $\otimes$) - (Element-wise)
#
# Phép nhân Hadamard là cốt lõi trong việc tính toán ảnh hưởng của **Hàm Kích hoạt** lên Gradient.
#
# #### Ứng dụng trong Backpropagation
#
# Phép nhân Hadamard được sử dụng để tính Gradient của hàm mất mát ($J$) đối với đầu vào chưa kích hoạt ($Z^{(i)}$):
#
# $$\frac{\partial J}{\partial Z^{(i)}} = \frac{\partial J}{\partial A^{(i)}} \odot \frac{\partial A^{(i)}}{\partial Z^{(i)}}$$
#
# * **Mục đích:** Kết hợp Gradient từ tầng sau ($\frac{\partial J}{\partial A^{(i)}}$) với Đạo hàm của Hàm Kích hoạt ($\frac{\partial A^{(i)}}{\partial Z^{(i)}}$). Vì hàm kích hoạt (như Sigmoid, ReLU) tác động độc lập lên từng nơ-ron, phép nhân này phải là **element-wise**.
# * **Công thức Đạo hàm Sigmoid (Ví dụ):** $\frac{\partial A^{(i)}}{\partial Z^{(i)}} = A^{(i)} \odot (1 - A^{(i)})$
#
# **Ví dụ:**
# * Giả sử Gradient từ tầng sau: $dA = \begin{pmatrix} -0.1 \\ 0.3 \end{pmatrix}$
# * Giả sử Đạo hàm của Activation: $g'(Z) = \begin{pmatrix} 0.2 \\ 0.25 \end{pmatrix}$
# $$\frac{\partial J}{\partial Z} = dA \odot g'(Z) = \begin{pmatrix} -0.1 \\ 0.3 \end{pmatrix} \odot \begin{pmatrix} 0.2 \\ 0.25 \end{pmatrix} = \begin{pmatrix} -0.02 \\ 0.075 \end{pmatrix}$$
#
# ---
#
# ## 3. ⚠️ Lưu ý Quan trọng
#
# * Hai phép toán này **KHÔNG THỂ THAY THẾ CHO NHAU**. Việc áp dụng sai phép toán sẽ làm hỏng kích thước ma trận và vi phạm quy tắc chuỗi của đạo hàm.
# * Trong nhiều tài liệu DL, ký hiệu $\otimes$ được sử dụng thay cho $\odot$ để chỉ Tích Hadamard. Luôn luôn kiểm tra chú thích của tài liệu (như trong công thức Backpropagation của bạn) để xác định rõ ý nghĩa của ký hiệu.
